# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(
    "D:/Study/SQL/database/retail_lab.db"
)

query = """
SELECT
    region
    count(*) as customer_count
FROM customers
GROUP BY region
ORDER BY customer_count desc
"""
print(query)
print(repr(query))

df = pd.read_sql(query, conn)
print(df)
# Out:
# SELECT
#     region
#     count(*) as customer_count
# FROM customers
# GROUP BY region
# ORDER BY customer_count desc
#
# '\nSELECT\n    region\n    count(*) as customer_count\nFROM customers\nGROUP BY region\nORDER BY customer_count desc\n'
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Kimt4\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: near "(": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 19
#      15 """
#      16 print(query)
#      17 print(repr(query))
#      18
# ---> 19 df = pd.read_sql(query, conn)
#      20 print(df)
#
# File c:\Users\Kimt4\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\Kimt4\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File c:\Users\Kimt4\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# SELECT
#     region
#     count(*) as customer_count
# FROM customers
# GROUP BY region
# ORDER BY customer_count desc
# ': near "(": syntax error
